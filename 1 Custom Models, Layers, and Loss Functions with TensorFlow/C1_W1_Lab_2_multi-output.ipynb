# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 901us/sample - loss: 261.1075 - y1_output_loss: 119.6268 - y2_output_loss: 138.9932 - y1_output_root_mean_squared_error: 10.9897 - y2_output_root_mean_squared_error: 11.8462 - val_loss: 40.2543 - val_y1_output_loss: 17.0375 - val_y2_output_loss: 22.0519 - val_y1_output_root_mean_squared_error: 4.1936 - val_y2_output_root_mean_squared_error: 4.7611
# Epoch 2/500
# 614/614 [==============================] - 0s 142us/sample - loss: 31.7390 - y1_output_loss: 11.8831 - y2_output_loss: 19.5953 - y1_output_root_mean_squared_error: 3.4608 - y2_output_root_mean_squared_error: 4.4454 - val_loss: 37.0627 - val_y1_output_loss: 15.7485 - val_y2_output_loss: 20.8726 - val_y1_output_root_mean_squared_error: 4.0035 - val_y2_output_root_mean_squared_error: 4.5863
# Epoch 3/500
# 614/614 [==============================] - 0s 133us/sample - loss: 25.9203 - y1_output_loss: 9.8127 - y2_output_loss: 16.1305 - y1_output_root_mean_squared_error: 3.1264 - y2_output_root_mean_squared_error: 4.0182 - val_loss: 26.7552 - val_y1_output_loss: 12.1938 - val_y2_output_loss: 13.9229 - val_y1_output_root_mean_squared_error: 3.5356 - val_y2_output_root_mean_squared_error: 3.7755
# Epoch 4/500
# 614/614 [==============================] - 0s 142us/sample - loss: 25.9730 - y1_output_loss: 9.3637 - y2_output_loss: 16.8905 - y1_output_root_mean_squared_error: 3.0290 - y2_output_root_mean_squared_error: 4.0986 - val_loss: 29.0182 - val_y1_output_loss: 12.7452 - val_y2_output_loss: 15.5781 - val_y1_output_root_mean_squared_error: 3.6230 - val_y2_output_root_mean_squared_error: 3.9865
# Epoch 5/500
# 614/614 [==============================] - 0s 138us/sample - loss: 22.6392 - y1_output_loss: 8.5113 - y2_output_loss: 13.9896 - y1_output_root_mean_squared_error: 2.9303 - y2_output_root_mean_squared_error: 3.7486 - val_loss: 32.8886 - val_y1_output_loss: 14.3043 - val_y2_output_loss: 18.8126 - val_y1_output_root_mean_squared_error: 3.7757 - val_y2_output_root_mean_squared_error: 4.3166
# Epoch 6/500
# 614/614 [==============================] - 0s 131us/sample - loss: 20.7803 - y1_output_loss: 8.0539 - y2_output_loss: 12.7534 - y1_output_root_mean_squared_error: 2.8428 - y2_output_root_mean_squared_error: 3.5636 - val_loss: 24.6322 - val_y1_output_loss: 12.0709 - val_y2_output_loss: 11.8568 - val_y1_output_root_mean_squared_error: 3.5295 - val_y2_output_root_mean_squared_error: 3.4892
# Epoch 7/500
# 614/614 [==============================] - 0s 127us/sample - loss: 23.2556 - y1_output_loss: 8.4778 - y2_output_loss: 14.7607 - y1_output_root_mean_squared_error: 2.9070 - y2_output_root_mean_squared_error: 3.8478 - val_loss: 27.5802 - val_y1_output_loss: 12.6779 - val_y2_output_loss: 14.4902 - val_y1_output_root_mean_squared_error: 3.5860 - val_y2_output_root_mean_squared_error: 3.8368
# Epoch 8/500
# 614/614 [==============================] - 0s 129us/sample - loss: 20.5169 - y1_output_loss: 7.8587 - y2_output_loss: 12.5100 - y1_output_root_mean_squared_error: 2.8147 - y2_output_root_mean_squared_error: 3.5489 - val_loss: 26.0542 - val_y1_output_loss: 11.7379 - val_y2_output_loss: 14.0529 - val_y1_output_root_mean_squared_error: 3.4482 - val_y2_output_root_mean_squared_error: 3.7635
# Epoch 9/500
# 614/614 [==============================] - 0s 130us/sample - loss: 23.6722 - y1_output_loss: 8.4837 - y2_output_loss: 14.9973 - y1_output_root_mean_squared_error: 2.9252 - y2_output_root_mean_squared_error: 3.8878 - val_loss: 24.5116 - val_y1_output_loss: 12.3360 - val_y2_output_loss: 11.8521 - val_y1_output_root_mean_squared_error: 3.5275 - val_y2_output_root_mean_squared_error: 3.4739
# Epoch 10/500
# 614/614 [==============================] - 0s 130us/sample - loss: 23.0832 - y1_output_loss: 8.4120 - y2_output_loss: 15.0149 - y1_output_root_mean_squared_error: 2.8783 - y2_output_root_mean_squared_error: 3.8469 - val_loss: 35.2014 - val_y1_output_loss: 12.5846 - val_y2_output_loss: 22.1950 - val_y1_output_root_mean_squared_error: 3.6030 - val_y2_output_root_mean_squared_error: 4.7138
# Epoch 11/500
# 614/614 [==============================] - 0s 134us/sample - loss: 19.9465 - y1_output_loss: 7.8545 - y2_output_loss: 12.5299 - y1_output_root_mean_squared_error: 2.7495 - y2_output_root_mean_squared_error: 3.5195 - val_loss: 23.4253 - val_y1_output_loss: 11.2525 - val_y2_output_loss: 11.7678 - val_y1_output_root_mean_squared_error: 3.3863 - val_y2_output_root_mean_squared_error: 3.4581
# Epoch 12/500
# 614/614 [==============================] - 0s 130us/sample - loss: 18.8980 - y1_output_loss: 7.2787 - y2_output_loss: 11.5120 - y1_output_root_mean_squared_error: 2.7097 - y2_output_root_mean_squared_error: 3.3993 - val_loss: 18.9850 - val_y1_output_loss: 9.1463 - val_y2_output_loss: 9.3154 - val_y1_output_root_mean_squared_error: 3.0707 - val_y2_output_root_mean_squared_error: 3.0913
# Epoch 13/500
# 614/614 [==============================] - 0s 137us/sample - loss: 17.3370 - y1_output_loss: 6.8873 - y2_output_loss: 10.6358 - y1_output_root_mean_squared_error: 2.5940 - y2_output_root_mean_squared_error: 3.2570 - val_loss: 59.4279 - val_y1_output_loss: 19.8663 - val_y2_output_loss: 40.3996 - val_y1_output_root_mean_squared_error: 4.4080 - val_y2_output_root_mean_squared_error: 6.3244
# Epoch 14/500
# 614/614 [==============================] - 0s 127us/sample - loss: 18.0981 - y1_output_loss: 6.6520 - y2_output_loss: 11.3805 - y1_output_root_mean_squared_error: 2.5809 - y2_output_root_mean_squared_error: 3.3819 - val_loss: 20.0378 - val_y1_output_loss: 10.0929 - val_y2_output_loss: 9.4154 - val_y1_output_root_mean_squared_error: 3.2134 - val_y2_output_root_mean_squared_error: 3.1164
# Epoch 15/500
# 614/614 [==============================] - 0s 126us/sample - loss: 18.9755 - y1_output_loss: 6.7997 - y2_output_loss: 12.0518 - y1_output_root_mean_squared_error: 2.6182 - y2_output_root_mean_squared_error: 3.4815 - val_loss: 22.0115 - val_y1_output_loss: 9.8286 - val_y2_output_loss: 11.9098 - val_y1_output_root_mean_squared_error: 3.1524 - val_y2_output_root_mean_squared_error: 3.4747
# Epoch 16/500
# 614/614 [==============================] - 0s 132us/sample - loss: 17.4740 - y1_output_loss: 6.2014 - y2_output_loss: 11.1290 - y1_output_root_mean_squared_error: 2.5014 - y2_output_root_mean_squared_error: 3.3491 - val_loss: 19.2300 - val_y1_output_loss: 8.4780 - val_y2_output_loss: 10.2291 - val_y1_output_root_mean_squared_error: 2.9639 - val_y2_output_root_mean_squared_error: 3.2319
# Epoch 17/500
# 614/614 [==============================] - 0s 133us/sample - loss: 14.3636 - y1_output_loss: 5.8327 - y2_output_loss: 8.6540 - y1_output_root_mean_squared_error: 2.3988 - y2_output_root_mean_squared_error: 2.9342 - val_loss: 22.5711 - val_y1_output_loss: 11.2268 - val_y2_output_loss: 11.4127 - val_y1_output_root_mean_squared_error: 3.3363 - val_y2_output_root_mean_squared_error: 3.3824
# Epoch 18/500
# 614/614 [==============================] - 0s 136us/sample - loss: 15.3639 - y1_output_loss: 5.7819 - y2_output_loss: 9.4432 - y1_output_root_mean_squared_error: 2.4155 - y2_output_root_mean_squared_error: 3.0870 - val_loss: 18.1512 - val_y1_output_loss: 8.4824 - val_y2_output_loss: 9.1379 - val_y1_output_root_mean_squared_error: 2.9618 - val_y2_output_root_mean_squared_error: 3.0625
# Epoch 19/500
# 614/614 [==============================] - 0s 128us/sample - loss: 14.6460 - y1_output_loss: 5.3118 - y2_output_loss: 9.3158 - y1_output_root_mean_squared_error: 2.3107 - y2_output_root_mean_squared_error: 3.0507 - val_loss: 15.8308 - val_y1_output_loss: 8.2634 - val_y2_output_loss: 7.2149 - val_y1_output_root_mean_squared_error: 2.8992 - val_y2_output_root_mean_squared_error: 2.7250
# Epoch 20/500
# 614/614 [==============================] - 0s 131us/sample - loss: 18.7755 - y1_output_loss: 6.6413 - y2_output_loss: 12.1416 - y1_output_root_mean_squared_error: 2.5805 - y2_output_root_mean_squared_error: 3.4809 - val_loss: 22.1989 - val_y1_output_loss: 8.2905 - val_y2_output_loss: 13.3289 - val_y1_output_root_mean_squared_error: 2.9292 - val_y2_output_root_mean_squared_error: 3.6904
# Epoch 21/500
# 614/614 [==============================] - 0s 128us/sample - loss: 13.7557 - y1_output_loss: 4.9477 - y2_output_loss: 8.6916 - y1_output_root_mean_squared_error: 2.2341 - y2_output_root_mean_squared_error: 2.9605 - val_loss: 16.8558 - val_y1_output_loss: 8.1285 - val_y2_output_loss: 8.2244 - val_y1_output_root_mean_squared_error: 2.8935 - val_y2_output_root_mean_squared_error: 2.9126
# Epoch 22/500
# 614/614 [==============================] - 0s 133us/sample - loss: 12.8958 - y1_output_loss: 5.0073 - y2_output_loss: 7.9748 - y1_output_root_mean_squared_error: 2.2215 - y2_output_root_mean_squared_error: 2.8214 - val_loss: 29.7342 - val_y1_output_loss: 13.7879 - val_y2_output_loss: 16.4045 - val_y1_output_root_mean_squared_error: 3.6730 - val_y2_output_root_mean_squared_error: 4.0303
# Epoch 23/500
# 614/614 [==============================] - 0s 142us/sample - loss: 14.5706 - y1_output_loss: 5.1803 - y2_output_loss: 9.6311 - y1_output_root_mean_squared_error: 2.2667 - y2_output_root_mean_squared_error: 3.0713 - val_loss: 14.9428 - val_y1_output_loss: 7.6592 - val_y2_output_loss: 6.8693 - val_y1_output_root_mean_squared_error: 2.8005 - val_y2_output_root_mean_squared_error: 2.6646
# Epoch 24/500
# 614/614 [==============================] - 0s 133us/sample - loss: 13.7479 - y1_output_loss: 5.1808 - y2_output_loss: 8.4896 - y1_output_root_mean_squared_error: 2.2816 - y2_output_root_mean_squared_error: 2.9227 - val_loss: 16.1626 - val_y1_output_loss: 7.2590 - val_y2_output_loss: 8.5122 - val_y1_output_root_mean_squared_error: 2.7285 - val_y2_output_root_mean_squared_error: 2.9526
# Epoch 25/500
# 614/614 [==============================] - 0s 133us/sample - loss: 11.7642 - y1_output_loss: 4.4383 - y2_output_loss: 7.2656 - y1_output_root_mean_squared_error: 2.1149 - y2_output_root_mean_squared_error: 2.7002 - val_loss: 14.5800 - val_y1_output_loss: 6.9029 - val_y2_output_loss: 7.3159 - val_y1_output_root_mean_squared_error: 2.6726 - val_y2_output_root_mean_squared_error: 2.7271
# Epoch 26/500
# 614/614 [==============================] - 0s 128us/sample - loss: 14.3549 - y1_output_loss: 4.9111 - y2_output_loss: 9.3673 - y1_output_root_mean_squared_error: 2.2254 - y2_output_root_mean_squared_error: 3.0664 - val_loss: 14.4409 - val_y1_output_loss: 6.8891 - val_y2_output_loss: 7.1634 - val_y1_output_root_mean_squared_error: 2.6640 - val_y2_output_root_mean_squared_error: 2.7100
# Epoch 27/500
# 614/614 [==============================] - 0s 131us/sample - loss: 14.1906 - y1_output_loss: 4.9706 - y2_output_loss: 9.0856 - y1_output_root_mean_squared_error: 2.2402 - y2_output_root_mean_squared_error: 3.0285 - val_loss: 14.2585 - val_y1_output_loss: 6.8397 - val_y2_output_loss: 7.2741 - val_y1_output_root_mean_squared_error: 2.6217 - val_y2_output_root_mean_squared_error: 2.7176
# Epoch 28/500
# 614/614 [==============================] - 0s 140us/sample - loss: 12.2608 - y1_output_loss: 4.3764 - y2_output_loss: 7.8291 - y1_output_root_mean_squared_error: 2.0938 - y2_output_root_mean_squared_error: 2.8066 - val_loss: 25.3704 - val_y1_output_loss: 9.7938 - val_y2_output_loss: 15.6962 - val_y1_output_root_mean_squared_error: 3.1131 - val_y2_output_root_mean_squared_error: 3.9597
# Epoch 29/500
# 614/614 [==============================] - 0s 128us/sample - loss: 12.4599 - y1_output_loss: 4.5027 - y2_output_loss: 7.9743 - y1_output_root_mean_squared_error: 2.1152 - y2_output_root_mean_squared_error: 2.8259 - val_loss: 12.6562 - val_y1_output_loss: 6.3865 - val_y2_output_loss: 6.0526 - val_y1_output_root_mean_squared_error: 2.5485 - val_y2_output_root_mean_squared_error: 2.4822
# Epoch 30/500
# 614/614 [==============================] - 0s 127us/sample - loss: 11.9886 - y1_output_loss: 4.4716 - y2_output_loss: 7.4813 - y1_output_root_mean_squared_error: 2.1170 - y2_output_root_mean_squared_error: 2.7399 - val_loss: 11.8910 - val_y1_output_loss: 5.8366 - val_y2_output_loss: 5.8508 - val_y1_output_root_mean_squared_error: 2.4299 - val_y2_output_root_mean_squared_error: 2.4468
# Epoch 31/500
# 614/614 [==============================] - 0s 126us/sample - loss: 10.3080 - y1_output_loss: 3.8391 - y2_output_loss: 6.4451 - y1_output_root_mean_squared_error: 1.9651 - y2_output_root_mean_squared_error: 2.5389 - val_loss: 21.7181 - val_y1_output_loss: 7.1166 - val_y2_output_loss: 14.3450 - val_y1_output_root_mean_squared_error: 2.7084 - val_y2_output_root_mean_squared_error: 3.7924
# Epoch 32/500
# 614/614 [==============================] - 0s 129us/sample - loss: 11.8379 - y1_output_loss: 4.3848 - y2_output_loss: 7.4291 - y1_output_root_mean_squared_error: 2.0991 - y2_output_root_mean_squared_error: 2.7261 - val_loss: 20.3245 - val_y1_output_loss: 7.4967 - val_y2_output_loss: 12.3543 - val_y1_output_root_mean_squared_error: 2.7849 - val_y2_output_root_mean_squared_error: 3.5453
# Epoch 33/500
# 614/614 [==============================] - 0s 126us/sample - loss: 11.3186 - y1_output_loss: 3.8335 - y2_output_loss: 7.4192 - y1_output_root_mean_squared_error: 1.9661 - y2_output_root_mean_squared_error: 2.7300 - val_loss: 12.4875 - val_y1_output_loss: 5.7584 - val_y2_output_loss: 6.3628 - val_y1_output_root_mean_squared_error: 2.4293 - val_y2_output_root_mean_squared_error: 2.5663
# Epoch 34/500
# 614/614 [==============================] - 0s 127us/sample - loss: 11.6873 - y1_output_loss: 4.0273 - y2_output_loss: 7.6883 - y1_output_root_mean_squared_error: 2.0018 - y2_output_root_mean_squared_error: 2.7713 - val_loss: 17.4124 - val_y1_output_loss: 7.2531 - val_y2_output_loss: 9.8892 - val_y1_output_root_mean_squared_error: 2.7059 - val_y2_output_root_mean_squared_error: 3.1765
# Epoch 35/500
# 614/614 [==============================] - 0s 126us/sample - loss: 9.7117 - y1_output_loss: 3.4942 - y2_output_loss: 6.1300 - y1_output_root_mean_squared_error: 1.8777 - y2_output_root_mean_squared_error: 2.4872 - val_loss: 15.3425 - val_y1_output_loss: 6.0392 - val_y2_output_loss: 9.0069 - val_y1_output_root_mean_squared_error: 2.4960 - val_y2_output_root_mean_squared_error: 3.0187
# Epoch 36/500
# 614/614 [==============================] - 0s 130us/sample - loss: 13.8756 - y1_output_loss: 4.2922 - y2_output_loss: 9.4582 - y1_output_root_mean_squared_error: 2.0813 - y2_output_root_mean_squared_error: 3.0893 - val_loss: 10.1395 - val_y1_output_loss: 5.1499 - val_y2_output_loss: 4.7357 - val_y1_output_root_mean_squared_error: 2.2985 - val_y2_output_root_mean_squared_error: 2.2037
# Epoch 37/500
# 614/614 [==============================] - 0s 128us/sample - loss: 10.8993 - y1_output_loss: 3.7540 - y2_output_loss: 7.1350 - y1_output_root_mean_squared_error: 1.9456 - y2_output_root_mean_squared_error: 2.6672 - val_loss: 16.9394 - val_y1_output_loss: 5.2232 - val_y2_output_loss: 11.5238 - val_y1_output_root_mean_squared_error: 2.3193 - val_y2_output_root_mean_squared_error: 3.4000
# Epoch 38/500
# 614/614 [==============================] - 0s 129us/sample - loss: 9.7891 - y1_output_loss: 3.7810 - y2_output_loss: 6.1394 - y1_output_root_mean_squared_error: 1.9304 - y2_output_root_mean_squared_error: 2.4622 - val_loss: 19.6438 - val_y1_output_loss: 8.5704 - val_y2_output_loss: 10.7231 - val_y1_output_root_mean_squared_error: 2.9479 - val_y2_output_root_mean_squared_error: 3.3096
# Epoch 39/500
# 614/614 [==============================] - 0s 127us/sample - loss: 13.2628 - y1_output_loss: 4.3544 - y2_output_loss: 9.0544 - y1_output_root_mean_squared_error: 2.0678 - y2_output_root_mean_squared_error: 2.9978 - val_loss: 41.8962 - val_y1_output_loss: 13.1607 - val_y2_output_loss: 29.6410 - val_y1_output_root_mean_squared_error: 3.5612 - val_y2_output_root_mean_squared_error: 5.4050
# Epoch 40/500
# 614/614 [==============================] - 0s 128us/sample - loss: 11.4078 - y1_output_loss: 3.7802 - y2_output_loss: 7.6018 - y1_output_root_mean_squared_error: 1.9394 - y2_output_root_mean_squared_error: 2.7653 - val_loss: 13.9778 - val_y1_output_loss: 5.4899 - val_y2_output_loss: 8.2396 - val_y1_output_root_mean_squared_error: 2.3570 - val_y2_output_root_mean_squared_error: 2.9021
# Epoch 41/500
# 614/614 [==============================] - 0s 151us/sample - loss: 8.5360 - y1_output_loss: 3.1623 - y2_output_loss: 5.6236 - y1_output_root_mean_squared_error: 1.7429 - y2_output_root_mean_squared_error: 2.3448 - val_loss: 43.4039 - val_y1_output_loss: 15.6857 - val_y2_output_loss: 29.1794 - val_y1_output_root_mean_squared_error: 3.8600 - val_y2_output_root_mean_squared_error: 5.3390
# Epoch 42/500
# 614/614 [==============================] - 0s 137us/sample - loss: 11.1151 - y1_output_loss: 3.6176 - y2_output_loss: 7.4631 - y1_output_root_mean_squared_error: 1.9057 - y2_output_root_mean_squared_error: 2.7356 - val_loss: 12.5096 - val_y1_output_loss: 3.9522 - val_y2_output_loss: 8.3904 - val_y1_output_root_mean_squared_error: 2.0089 - val_y2_output_root_mean_squared_error: 2.9110
# Epoch 43/500
# 614/614 [==============================] - 0s 127us/sample - loss: 9.7548 - y1_output_loss: 3.1802 - y2_output_loss: 6.5867 - y1_output_root_mean_squared_error: 1.7871 - y2_output_root_mean_squared_error: 2.5614 - val_loss: 17.7453 - val_y1_output_loss: 5.0469 - val_y2_output_loss: 12.6093 - val_y1_output_root_mean_squared_error: 2.2724 - val_y2_output_root_mean_squared_error: 3.5470
# Epoch 44/500
# 614/614 [==============================] - 0s 128us/sample - loss: 9.6194 - y1_output_loss: 3.0750 - y2_output_loss: 6.5452 - y1_output_root_mean_squared_error: 1.7603 - y2_output_root_mean_squared_error: 2.5536 - val_loss: 9.1831 - val_y1_output_loss: 3.6321 - val_y2_output_loss: 5.3841 - val_y1_output_root_mean_squared_error: 1.9232 - val_y2_output_root_mean_squared_error: 2.3418
# Epoch 45/500
# 614/614 [==============================] - 0s 133us/sample - loss: 7.4917 - y1_output_loss: 2.6293 - y2_output_loss: 4.7932 - y1_output_root_mean_squared_error: 1.6292 - y2_output_root_mean_squared_error: 2.1994 - val_loss: 7.9449 - val_y1_output_loss: 3.4709 - val_y2_output_loss: 4.3365 - val_y1_output_root_mean_squared_error: 1.8699 - val_y2_output_root_mean_squared_error: 2.1091
# Epoch 46/500
# 614/614 [==============================] - 0s 126us/sample - loss: 6.5505 - y1_output_loss: 2.4299 - y2_output_loss: 4.0905 - y1_output_root_mean_squared_error: 1.5616 - y2_output_root_mean_squared_error: 2.0278 - val_loss: 13.7652 - val_y1_output_loss: 5.8397 - val_y2_output_loss: 8.2700 - val_y1_output_root_mean_squared_error: 2.3673 - val_y2_output_root_mean_squared_error: 2.8568
# Epoch 47/500
# 614/614 [==============================] - 0s 143us/sample - loss: 7.0824 - y1_output_loss: 2.6195 - y2_output_loss: 4.4505 - y1_output_root_mean_squared_error: 1.6162 - y2_output_root_mean_squared_error: 2.1143 - val_loss: 11.7888 - val_y1_output_loss: 5.9248 - val_y2_output_loss: 5.6909 - val_y1_output_root_mean_squared_error: 2.4374 - val_y2_output_root_mean_squared_error: 2.4182
# Epoch 48/500
# 614/614 [==============================] - 0s 145us/sample - loss: 7.3755 - y1_output_loss: 2.4613 - y2_output_loss: 4.9201 - y1_output_root_mean_squared_error: 1.5619 - y2_output_root_mean_squared_error: 2.2217 - val_loss: 8.6121 - val_y1_output_loss: 3.8057 - val_y2_output_loss: 4.6112 - val_y1_output_root_mean_squared_error: 1.9660 - val_y2_output_root_mean_squared_error: 2.1788
# Epoch 49/500
# 614/614 [==============================] - 0s 154us/sample - loss: 7.2441 - y1_output_loss: 2.4515 - y2_output_loss: 4.7276 - y1_output_root_mean_squared_error: 1.5726 - y2_output_root_mean_squared_error: 2.1843 - val_loss: 6.9245 - val_y1_output_loss: 3.0119 - val_y2_output_loss: 3.8130 - val_y1_output_root_mean_squared_error: 1.7450 - val_y2_output_root_mean_squared_error: 1.9696
# Epoch 50/500
# 614/614 [==============================] - 0s 126us/sample - loss: 9.2175 - y1_output_loss: 3.0425 - y2_output_loss: 6.0888 - y1_output_root_mean_squared_error: 1.7521 - y2_output_root_mean_squared_error: 2.4795 - val_loss: 7.1376 - val_y1_output_loss: 2.9651 - val_y2_output_loss: 4.1034 - val_y1_output_root_mean_squared_error: 1.7220 - val_y2_output_root_mean_squared_error: 2.0426
# Epoch 51/500
# 614/614 [==============================] - 0s 125us/sample - loss: 7.7421 - y1_output_loss: 2.7023 - y2_output_loss: 4.9920 - y1_output_root_mean_squared_error: 1.6448 - y2_output_root_mean_squared_error: 2.2442 - val_loss: 6.8969 - val_y1_output_loss: 2.9064 - val_y2_output_loss: 3.9373 - val_y1_output_root_mean_squared_error: 1.7061 - val_y2_output_root_mean_squared_error: 1.9965
# Epoch 52/500
# 614/614 [==============================] - 0s 129us/sample - loss: 7.8835 - y1_output_loss: 2.6054 - y2_output_loss: 5.2998 - y1_output_root_mean_squared_error: 1.6141 - y2_output_root_mean_squared_error: 2.2974 - val_loss: 10.9354 - val_y1_output_loss: 3.7648 - val_y2_output_loss: 7.0282 - val_y1_output_root_mean_squared_error: 1.9576 - val_y2_output_root_mean_squared_error: 2.6652
# Epoch 53/500
# 614/614 [==============================] - 0s 126us/sample - loss: 6.2330 - y1_output_loss: 2.1952 - y2_output_loss: 4.0551 - y1_output_root_mean_squared_error: 1.4858 - y2_output_root_mean_squared_error: 2.0064 - val_loss: 22.3317 - val_y1_output_loss: 5.3332 - val_y2_output_loss: 16.9171 - val_y1_output_root_mean_squared_error: 2.3183 - val_y2_output_root_mean_squared_error: 4.1179
# Epoch 54/500
# 614/614 [==============================] - 0s 133us/sample - loss: 6.7520 - y1_output_loss: 2.1848 - y2_output_loss: 4.5111 - y1_output_root_mean_squared_error: 1.4840 - y2_output_root_mean_squared_error: 2.1330 - val_loss: 7.1008 - val_y1_output_loss: 3.1319 - val_y2_output_loss: 3.8869 - val_y1_output_root_mean_squared_error: 1.7777 - val_y2_output_root_mean_squared_error: 1.9851
# Epoch 55/500
# 614/614 [==============================] - 0s 129us/sample - loss: 8.8883 - y1_output_loss: 3.0765 - y2_output_loss: 5.7553 - y1_output_root_mean_squared_error: 1.7559 - y2_output_root_mean_squared_error: 2.4094 - val_loss: 7.7652 - val_y1_output_loss: 3.1402 - val_y2_output_loss: 4.4674 - val_y1_output_root_mean_squared_error: 1.7871 - val_y2_output_root_mean_squared_error: 2.1381
# Epoch 56/500
# 614/614 [==============================] - 0s 133us/sample - loss: 8.3188 - y1_output_loss: 2.9033 - y2_output_loss: 5.4612 - y1_output_root_mean_squared_error: 1.7035 - y2_output_root_mean_squared_error: 2.3274 - val_loss: 6.6303 - val_y1_output_loss: 2.6694 - val_y2_output_loss: 3.8685 - val_y1_output_root_mean_squared_error: 1.6343 - val_y2_output_root_mean_squared_error: 1.9898
# Epoch 57/500
# 614/614 [==============================] - 0s 128us/sample - loss: 5.5618 - y1_output_loss: 1.9671 - y2_output_loss: 3.6173 - y1_output_root_mean_squared_error: 1.4031 - y2_output_root_mean_squared_error: 1.8955 - val_loss: 18.4332 - val_y1_output_loss: 5.0650 - val_y2_output_loss: 13.5527 - val_y1_output_root_mean_squared_error: 2.2474 - val_y2_output_root_mean_squared_error: 3.6582
# Epoch 58/500
# 614/614 [==============================] - 0s 140us/sample - loss: 6.2405 - y1_output_loss: 2.0159 - y2_output_loss: 4.1797 - y1_output_root_mean_squared_error: 1.4239 - y2_output_root_mean_squared_error: 2.0526 - val_loss: 6.1707 - val_y1_output_loss: 2.2482 - val_y2_output_loss: 3.8691 - val_y1_output_root_mean_squared_error: 1.4976 - val_y2_output_root_mean_squared_error: 1.9819
# Epoch 59/500
# 614/614 [==============================] - 0s 145us/sample - loss: 5.5849 - y1_output_loss: 1.8524 - y2_output_loss: 3.6811 - y1_output_root_mean_squared_error: 1.3671 - y2_output_root_mean_squared_error: 1.9277 - val_loss: 6.6524 - val_y1_output_loss: 2.8501 - val_y2_output_loss: 3.8438 - val_y1_output_root_mean_squared_error: 1.6683 - val_y2_output_root_mean_squared_error: 1.9670
# Epoch 60/500
# 614/614 [==============================] - 0s 140us/sample - loss: 7.2542 - y1_output_loss: 2.4184 - y2_output_loss: 4.8459 - y1_output_root_mean_squared_error: 1.5505 - y2_output_root_mean_squared_error: 2.2023 - val_loss: 9.7342 - val_y1_output_loss: 3.9052 - val_y2_output_loss: 5.7214 - val_y1_output_root_mean_squared_error: 1.9882 - val_y2_output_root_mean_squared_error: 2.4044
# Epoch 61/500
# 614/614 [==============================] - 0s 140us/sample - loss: 6.2659 - y1_output_loss: 1.9682 - y2_output_loss: 4.2460 - y1_output_root_mean_squared_error: 1.4078 - y2_output_root_mean_squared_error: 2.0698 - val_loss: 5.8337 - val_y1_output_loss: 2.3153 - val_y2_output_loss: 3.4382 - val_y1_output_root_mean_squared_error: 1.5144 - val_y2_output_root_mean_squared_error: 1.8816
# Epoch 62/500
# 614/614 [==============================] - 0s 128us/sample - loss: 6.0164 - y1_output_loss: 1.9052 - y2_output_loss: 4.1187 - y1_output_root_mean_squared_error: 1.3830 - y2_output_root_mean_squared_error: 2.0258 - val_loss: 10.4095 - val_y1_output_loss: 3.3002 - val_y2_output_loss: 6.9635 - val_y1_output_root_mean_squared_error: 1.8231 - val_y2_output_root_mean_squared_error: 2.6619
# Epoch 63/500
# 614/614 [==============================] - 0s 129us/sample - loss: 7.1753 - y1_output_loss: 2.1677 - y2_output_loss: 5.0235 - y1_output_root_mean_squared_error: 1.4784 - y2_output_root_mean_squared_error: 2.2337 - val_loss: 12.8421 - val_y1_output_loss: 3.0462 - val_y2_output_loss: 9.6105 - val_y1_output_root_mean_squared_error: 1.7584 - val_y2_output_root_mean_squared_error: 3.1225
# Epoch 64/500
# 614/614 [==============================] - 0s 132us/sample - loss: 5.9210 - y1_output_loss: 1.9798 - y2_output_loss: 3.9234 - y1_output_root_mean_squared_error: 1.4087 - y2_output_root_mean_squared_error: 1.9841 - val_loss: 7.1824 - val_y1_output_loss: 2.6118 - val_y2_output_loss: 4.5184 - val_y1_output_root_mean_squared_error: 1.6112 - val_y2_output_root_mean_squared_error: 2.1416
# Epoch 65/500
# 614/614 [==============================] - 0s 127us/sample - loss: 5.5896 - y1_output_loss: 1.9586 - y2_output_loss: 3.5988 - y1_output_root_mean_squared_error: 1.4012 - y2_output_root_mean_squared_error: 1.9043 - val_loss: 6.3354 - val_y1_output_loss: 2.2649 - val_y2_output_loss: 4.0069 - val_y1_output_root_mean_squared_error: 1.5007 - val_y2_output_root_mean_squared_error: 2.0207
# Epoch 66/500
# 614/614 [==============================] - 0s 128us/sample - loss: 5.4058 - y1_output_loss: 1.7422 - y2_output_loss: 3.6715 - y1_output_root_mean_squared_error: 1.3161 - y2_output_root_mean_squared_error: 1.9167 - val_loss: 13.1289 - val_y1_output_loss: 4.9675 - val_y2_output_loss: 8.0004 - val_y1_output_root_mean_squared_error: 2.2358 - val_y2_output_root_mean_squared_error: 2.8513
# Epoch 67/500
# 614/614 [==============================] - 0s 136us/sample - loss: 4.6011 - y1_output_loss: 1.6288 - y2_output_loss: 3.0347 - y1_output_root_mean_squared_error: 1.2753 - y2_output_root_mean_squared_error: 1.7248 - val_loss: 13.0700 - val_y1_output_loss: 2.4151 - val_y2_output_loss: 10.7195 - val_y1_output_root_mean_squared_error: 1.5325 - val_y2_output_root_mean_squared_error: 3.2744
# Epoch 68/500
# 614/614 [==============================] - 0s 129us/sample - loss: 6.2317 - y1_output_loss: 2.0245 - y2_output_loss: 4.2436 - y1_output_root_mean_squared_error: 1.4181 - y2_output_root_mean_squared_error: 2.0545 - val_loss: 8.6621 - val_y1_output_loss: 3.5079 - val_y2_output_loss: 5.3403 - val_y1_output_root_mean_squared_error: 1.8410 - val_y2_output_root_mean_squared_error: 2.2963
# Epoch 69/500
# 614/614 [==============================] - 0s 126us/sample - loss: 5.2702 - y1_output_loss: 1.8237 - y2_output_loss: 3.4877 - y1_output_root_mean_squared_error: 1.3441 - y2_output_root_mean_squared_error: 1.8611 - val_loss: 14.7225 - val_y1_output_loss: 4.7429 - val_y2_output_loss: 10.2408 - val_y1_output_root_mean_squared_error: 2.1389 - val_y2_output_root_mean_squared_error: 3.1855
# Epoch 70/500
# 614/614 [==============================] - 0s 131us/sample - loss: 5.5237 - y1_output_loss: 1.6399 - y2_output_loss: 3.8655 - y1_output_root_mean_squared_error: 1.2837 - y2_output_root_mean_squared_error: 1.9687 - val_loss: 5.9132 - val_y1_output_loss: 2.3160 - val_y2_output_loss: 3.6624 - val_y1_output_root_mean_squared_error: 1.4970 - val_y2_output_root_mean_squared_error: 1.9163
# Epoch 71/500
# 614/614 [==============================] - 0s 131us/sample - loss: 8.4263 - y1_output_loss: 2.7846 - y2_output_loss: 5.5826 - y1_output_root_mean_squared_error: 1.6758 - y2_output_root_mean_squared_error: 2.3702 - val_loss: 9.4917 - val_y1_output_loss: 2.3063 - val_y2_output_loss: 7.1261 - val_y1_output_root_mean_squared_error: 1.5057 - val_y2_output_root_mean_squared_error: 2.6879
# Epoch 72/500
# 614/614 [==============================] - 0s 129us/sample - loss: 4.9877 - y1_output_loss: 1.6064 - y2_output_loss: 3.4193 - y1_output_root_mean_squared_error: 1.2622 - y2_output_root_mean_squared_error: 1.8424 - val_loss: 37.6411 - val_y1_output_loss: 13.2670 - val_y2_output_loss: 24.6950 - val_y1_output_root_mean_squared_error: 3.6086 - val_y2_output_root_mean_squared_error: 4.9618
# Epoch 73/500
# 614/614 [==============================] - 0s 132us/sample - loss: 4.8814 - y1_output_loss: 1.5612 - y2_output_loss: 3.3041 - y1_output_root_mean_squared_error: 1.2521 - y2_output_root_mean_squared_error: 1.8203 - val_loss: 6.3667 - val_y1_output_loss: 2.1685 - val_y2_output_loss: 4.0700 - val_y1_output_root_mean_squared_error: 1.4721 - val_y2_output_root_mean_squared_error: 2.0493
# Epoch 74/500
# 614/614 [==============================] - 0s 129us/sample - loss: 4.3631 - y1_output_loss: 1.5212 - y2_output_loss: 2.8289 - y1_output_root_mean_squared_error: 1.2309 - y2_output_root_mean_squared_error: 1.6876 - val_loss: 6.8229 - val_y1_output_loss: 2.4369 - val_y2_output_loss: 4.5845 - val_y1_output_root_mean_squared_error: 1.5191 - val_y2_output_root_mean_squared_error: 2.1249
# Epoch 75/500
# 614/614 [==============================] - 0s 127us/sample - loss: 4.6156 - y1_output_loss: 1.4070 - y2_output_loss: 3.1935 - y1_output_root_mean_squared_error: 1.1889 - y2_output_root_mean_squared_error: 1.7894 - val_loss: 6.2436 - val_y1_output_loss: 1.8906 - val_y2_output_loss: 4.2419 - val_y1_output_root_mean_squared_error: 1.3715 - val_y2_output_root_mean_squared_error: 2.0887
# Epoch 76/500
# 614/614 [==============================] - 0s 128us/sample - loss: 5.5659 - y1_output_loss: 1.6171 - y2_output_loss: 3.9317 - y1_output_root_mean_squared_error: 1.2674 - y2_output_root_mean_squared_error: 1.9899 - val_loss: 10.0048 - val_y1_output_loss: 4.5292 - val_y2_output_loss: 5.2857 - val_y1_output_root_mean_squared_error: 2.1467 - val_y2_output_root_mean_squared_error: 2.3230
# Epoch 77/500
# 614/614 [==============================] - 0s 127us/sample - loss: 4.2482 - y1_output_loss: 1.4018 - y2_output_loss: 2.8198 - y1_output_root_mean_squared_error: 1.1884 - y2_output_root_mean_squared_error: 1.6840 - val_loss: 6.0117 - val_y1_output_loss: 1.8750 - val_y2_output_loss: 4.2890 - val_y1_output_root_mean_squared_error: 1.3323 - val_y2_output_root_mean_squared_error: 2.0583
# Epoch 78/500
# 614/614 [==============================] - 0s 125us/sample - loss: 3.7569 - y1_output_loss: 1.2261 - y2_output_loss: 2.5168 - y1_output_root_mean_squared_error: 1.1028 - y2_output_root_mean_squared_error: 1.5940 - val_loss: 5.6113 - val_y1_output_loss: 2.2186 - val_y2_output_loss: 3.5345 - val_y1_output_root_mean_squared_error: 1.4454 - val_y2_output_root_mean_squared_error: 1.8767
# Epoch 79/500
# 614/614 [==============================] - 0s 125us/sample - loss: 4.4241 - y1_output_loss: 1.3168 - y2_output_loss: 3.1241 - y1_output_root_mean_squared_error: 1.1501 - y2_output_root_mean_squared_error: 1.7611 - val_loss: 6.5088 - val_y1_output_loss: 2.0360 - val_y2_output_loss: 4.6997 - val_y1_output_root_mean_squared_error: 1.3781 - val_y2_output_root_mean_squared_error: 2.1470
# Epoch 80/500
# 614/614 [==============================] - 0s 126us/sample - loss: 3.5945 - y1_output_loss: 1.1593 - y2_output_loss: 2.4389 - y1_output_root_mean_squared_error: 1.0722 - y2_output_root_mean_squared_error: 1.5636 - val_loss: 5.4953 - val_y1_output_loss: 2.2892 - val_y2_output_loss: 3.2535 - val_y1_output_root_mean_squared_error: 1.4851 - val_y2_output_root_mean_squared_error: 1.8137
# Epoch 81/500
# 614/614 [==============================] - 0s 126us/sample - loss: 3.2192 - y1_output_loss: 1.0775 - y2_output_loss: 2.1261 - y1_output_root_mean_squared_error: 1.0419 - y2_output_root_mean_squared_error: 1.4607 - val_loss: 5.2800 - val_y1_output_loss: 1.4274 - val_y2_output_loss: 3.9323 - val_y1_output_root_mean_squared_error: 1.1719 - val_y2_output_root_mean_squared_error: 1.9765
# Epoch 82/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.4532 - y1_output_loss: 1.0697 - y2_output_loss: 2.3689 - y1_output_root_mean_squared_error: 1.0335 - y2_output_root_mean_squared_error: 1.5444 - val_loss: 4.9200 - val_y1_output_loss: 1.5140 - val_y2_output_loss: 3.3153 - val_y1_output_root_mean_squared_error: 1.2268 - val_y2_output_root_mean_squared_error: 1.8480
# Epoch 83/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.4899 - y1_output_loss: 1.0126 - y2_output_loss: 2.4954 - y1_output_root_mean_squared_error: 1.0109 - y2_output_root_mean_squared_error: 1.5710 - val_loss: 8.0746 - val_y1_output_loss: 1.4855 - val_y2_output_loss: 6.4208 - val_y1_output_root_mean_squared_error: 1.2055 - val_y2_output_root_mean_squared_error: 2.5732
# Epoch 84/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.3169 - y1_output_loss: 1.0202 - y2_output_loss: 2.2839 - y1_output_root_mean_squared_error: 1.0126 - y2_output_root_mean_squared_error: 1.5138 - val_loss: 5.4569 - val_y1_output_loss: 1.1978 - val_y2_output_loss: 4.2734 - val_y1_output_root_mean_squared_error: 1.0797 - val_y2_output_root_mean_squared_error: 2.0715
# Epoch 85/500
# 614/614 [==============================] - 0s 125us/sample - loss: 5.0315 - y1_output_loss: 1.5240 - y2_output_loss: 3.5115 - y1_output_root_mean_squared_error: 1.2338 - y2_output_root_mean_squared_error: 1.8733 - val_loss: 9.5975 - val_y1_output_loss: 2.5420 - val_y2_output_loss: 7.2711 - val_y1_output_root_mean_squared_error: 1.5567 - val_y2_output_root_mean_squared_error: 2.6785
# Epoch 86/500
# 614/614 [==============================] - 0s 124us/sample - loss: 3.5177 - y1_output_loss: 1.0554 - y2_output_loss: 2.4287 - y1_output_root_mean_squared_error: 1.0322 - y2_output_root_mean_squared_error: 1.5660 - val_loss: 3.8906 - val_y1_output_loss: 1.1898 - val_y2_output_loss: 2.6841 - val_y1_output_root_mean_squared_error: 1.0824 - val_y2_output_root_mean_squared_error: 1.6489
# Epoch 87/500
# 614/614 [==============================] - 0s 125us/sample - loss: 5.5598 - y1_output_loss: 1.7441 - y2_output_loss: 3.7630 - y1_output_root_mean_squared_error: 1.3269 - y2_output_root_mean_squared_error: 1.9492 - val_loss: 7.8391 - val_y1_output_loss: 2.4932 - val_y2_output_loss: 5.1646 - val_y1_output_root_mean_squared_error: 1.5931 - val_y2_output_root_mean_squared_error: 2.3024
# Epoch 88/500
# 614/614 [==============================] - 0s 128us/sample - loss: 4.1575 - y1_output_loss: 1.1688 - y2_output_loss: 2.9523 - y1_output_root_mean_squared_error: 1.0858 - y2_output_root_mean_squared_error: 1.7258 - val_loss: 3.6693 - val_y1_output_loss: 1.2143 - val_y2_output_loss: 2.4833 - val_y1_output_root_mean_squared_error: 1.0809 - val_y2_output_root_mean_squared_error: 1.5815
# Epoch 89/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.3014 - y1_output_loss: 0.9511 - y2_output_loss: 2.3343 - y1_output_root_mean_squared_error: 0.9738 - y2_output_root_mean_squared_error: 1.5340 - val_loss: 10.1974 - val_y1_output_loss: 4.3265 - val_y2_output_loss: 5.9142 - val_y1_output_root_mean_squared_error: 2.0632 - val_y2_output_root_mean_squared_error: 2.4373
# Epoch 90/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.9890 - y1_output_loss: 0.8522 - y2_output_loss: 2.1249 - y1_output_root_mean_squared_error: 0.9231 - y2_output_root_mean_squared_error: 1.4618 - val_loss: 3.4465 - val_y1_output_loss: 0.9481 - val_y2_output_loss: 2.4715 - val_y1_output_root_mean_squared_error: 0.9539 - val_y2_output_root_mean_squared_error: 1.5927
# Epoch 91/500
# 614/614 [==============================] - 0s 137us/sample - loss: 5.4419 - y1_output_loss: 1.6389 - y2_output_loss: 3.7872 - y1_output_root_mean_squared_error: 1.2810 - y2_output_root_mean_squared_error: 1.9496 - val_loss: 7.1670 - val_y1_output_loss: 2.3718 - val_y2_output_loss: 4.6795 - val_y1_output_root_mean_squared_error: 1.5513 - val_y2_output_root_mean_squared_error: 2.1818
# Epoch 92/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.5098 - y1_output_loss: 0.7510 - y2_output_loss: 1.7500 - y1_output_root_mean_squared_error: 0.8699 - y2_output_root_mean_squared_error: 1.3240 - val_loss: 3.2556 - val_y1_output_loss: 0.8712 - val_y2_output_loss: 2.3508 - val_y1_output_root_mean_squared_error: 0.9237 - val_y2_output_root_mean_squared_error: 1.5499
# Epoch 93/500
# 614/614 [==============================] - 0s 137us/sample - loss: 3.2320 - y1_output_loss: 0.9448 - y2_output_loss: 2.2730 - y1_output_root_mean_squared_error: 0.9747 - y2_output_root_mean_squared_error: 1.5106 - val_loss: 3.7691 - val_y1_output_loss: 0.8562 - val_y2_output_loss: 2.9264 - val_y1_output_root_mean_squared_error: 0.9185 - val_y2_output_root_mean_squared_error: 1.7104
# Epoch 94/500
# 614/614 [==============================] - 0s 141us/sample - loss: 2.6415 - y1_output_loss: 0.7516 - y2_output_loss: 1.9283 - y1_output_root_mean_squared_error: 0.8699 - y2_output_root_mean_squared_error: 1.3729 - val_loss: 6.1146 - val_y1_output_loss: 1.0411 - val_y2_output_loss: 4.9685 - val_y1_output_root_mean_squared_error: 1.0185 - val_y2_output_root_mean_squared_error: 2.2533
# Epoch 95/500
# 614/614 [==============================] - 0s 137us/sample - loss: 3.4659 - y1_output_loss: 0.9379 - y2_output_loss: 2.5004 - y1_output_root_mean_squared_error: 0.9729 - y2_output_root_mean_squared_error: 1.5872 - val_loss: 3.5730 - val_y1_output_loss: 0.8191 - val_y2_output_loss: 2.6932 - val_y1_output_root_mean_squared_error: 0.9017 - val_y2_output_root_mean_squared_error: 1.6613
# Epoch 96/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.7432 - y1_output_loss: 0.7923 - y2_output_loss: 1.9332 - y1_output_root_mean_squared_error: 0.8902 - y2_output_root_mean_squared_error: 1.3967 - val_loss: 3.9420 - val_y1_output_loss: 1.2243 - val_y2_output_loss: 2.7577 - val_y1_output_root_mean_squared_error: 1.0880 - val_y2_output_root_mean_squared_error: 1.6608
# Epoch 97/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.6215 - y1_output_loss: 0.7990 - y2_output_loss: 1.8088 - y1_output_root_mean_squared_error: 0.8938 - y2_output_root_mean_squared_error: 1.3501 - val_loss: 3.8113 - val_y1_output_loss: 0.8830 - val_y2_output_loss: 2.9596 - val_y1_output_root_mean_squared_error: 0.9191 - val_y2_output_root_mean_squared_error: 1.7224
# Epoch 98/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.0825 - y1_output_loss: 0.6233 - y2_output_loss: 1.4457 - y1_output_root_mean_squared_error: 0.7894 - y2_output_root_mean_squared_error: 1.2081 - val_loss: 3.9299 - val_y1_output_loss: 1.2193 - val_y2_output_loss: 2.6526 - val_y1_output_root_mean_squared_error: 1.1072 - val_y2_output_root_mean_squared_error: 1.6444
# Epoch 99/500
# 614/614 [==============================] - 0s 126us/sample - loss: 2.3260 - y1_output_loss: 0.6722 - y2_output_loss: 1.6626 - y1_output_root_mean_squared_error: 0.8084 - y2_output_root_mean_squared_error: 1.2932 - val_loss: 3.7526 - val_y1_output_loss: 1.2555 - val_y2_output_loss: 2.5328 - val_y1_output_root_mean_squared_error: 1.0990 - val_y2_output_root_mean_squared_error: 1.5953
# Epoch 100/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.5257 - y1_output_loss: 0.6883 - y2_output_loss: 1.8222 - y1_output_root_mean_squared_error: 0.8312 - y2_output_root_mean_squared_error: 1.3546 - val_loss: 3.7030 - val_y1_output_loss: 0.7857 - val_y2_output_loss: 2.8619 - val_y1_output_root_mean_squared_error: 0.8825 - val_y2_output_root_mean_squared_error: 1.7100
# Epoch 101/500
# 614/614 [==============================] - 0s 137us/sample - loss: 1.9846 - y1_output_loss: 0.5850 - y2_output_loss: 1.4239 - y1_output_root_mean_squared_error: 0.7643 - y2_output_root_mean_squared_error: 1.1834 - val_loss: 5.4947 - val_y1_output_loss: 1.5931 - val_y2_output_loss: 3.9781 - val_y1_output_root_mean_squared_error: 1.2313 - val_y2_output_root_mean_squared_error: 1.9946
# Epoch 102/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.3142 - y1_output_loss: 0.7814 - y2_output_loss: 2.5292 - y1_output_root_mean_squared_error: 0.8866 - y2_output_root_mean_squared_error: 1.5900 - val_loss: 6.8141 - val_y1_output_loss: 1.2414 - val_y2_output_loss: 5.8034 - val_y1_output_root_mean_squared_error: 1.0676 - val_y2_output_root_mean_squared_error: 2.3821
# Epoch 103/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.3471 - y1_output_loss: 0.9055 - y2_output_loss: 2.4126 - y1_output_root_mean_squared_error: 0.9558 - y2_output_root_mean_squared_error: 1.5600 - val_loss: 2.6154 - val_y1_output_loss: 0.6826 - val_y2_output_loss: 1.9332 - val_y1_output_root_mean_squared_error: 0.8094 - val_y2_output_root_mean_squared_error: 1.4001
# Epoch 104/500
# 614/614 [==============================] - 0s 129us/sample - loss: 1.8951 - y1_output_loss: 0.5253 - y2_output_loss: 1.3716 - y1_output_root_mean_squared_error: 0.7280 - y2_output_root_mean_squared_error: 1.1684 - val_loss: 3.5734 - val_y1_output_loss: 1.1043 - val_y2_output_loss: 2.4423 - val_y1_output_root_mean_squared_error: 1.0410 - val_y2_output_root_mean_squared_error: 1.5779
# Epoch 105/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.4128 - y1_output_loss: 0.6693 - y2_output_loss: 1.8081 - y1_output_root_mean_squared_error: 0.7993 - y2_output_root_mean_squared_error: 1.3319 - val_loss: 14.4312 - val_y1_output_loss: 5.7107 - val_y2_output_loss: 8.4610 - val_y1_output_root_mean_squared_error: 2.4142 - val_y2_output_root_mean_squared_error: 2.9330
# Epoch 106/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.3296 - y1_output_loss: 0.7417 - y2_output_loss: 1.6424 - y1_output_root_mean_squared_error: 0.8590 - y2_output_root_mean_squared_error: 1.2616 - val_loss: 7.8992 - val_y1_output_loss: 1.7257 - val_y2_output_loss: 6.3880 - val_y1_output_root_mean_squared_error: 1.2723 - val_y2_output_root_mean_squared_error: 2.5061
# Epoch 107/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.7484 - y1_output_loss: 0.9188 - y2_output_loss: 1.8481 - y1_output_root_mean_squared_error: 0.9614 - y2_output_root_mean_squared_error: 1.3506 - val_loss: 7.4027 - val_y1_output_loss: 1.2209 - val_y2_output_loss: 6.1508 - val_y1_output_root_mean_squared_error: 1.1119 - val_y2_output_root_mean_squared_error: 2.4832
# Epoch 108/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.8179 - y1_output_loss: 0.6682 - y2_output_loss: 2.1449 - y1_output_root_mean_squared_error: 0.8139 - y2_output_root_mean_squared_error: 1.4682 - val_loss: 3.0163 - val_y1_output_loss: 0.8965 - val_y2_output_loss: 2.1237 - val_y1_output_root_mean_squared_error: 0.9331 - val_y2_output_root_mean_squared_error: 1.4648
# Epoch 109/500
# 614/614 [==============================] - 0s 131us/sample - loss: 5.9257 - y1_output_loss: 1.7437 - y2_output_loss: 4.1302 - y1_output_root_mean_squared_error: 1.3266 - y2_output_root_mean_squared_error: 2.0410 - val_loss: 3.1911 - val_y1_output_loss: 0.8847 - val_y2_output_loss: 2.3084 - val_y1_output_root_mean_squared_error: 0.9210 - val_y2_output_root_mean_squared_error: 1.5306
# Epoch 110/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.2913 - y1_output_loss: 0.6488 - y2_output_loss: 1.6393 - y1_output_root_mean_squared_error: 0.8009 - y2_output_root_mean_squared_error: 1.2845 - val_loss: 9.1661 - val_y1_output_loss: 2.3708 - val_y2_output_loss: 6.6043 - val_y1_output_root_mean_squared_error: 1.5610 - val_y2_output_root_mean_squared_error: 2.5941
# Epoch 111/500
# 614/614 [==============================] - 0s 126us/sample - loss: 2.5654 - y1_output_loss: 0.7950 - y2_output_loss: 1.7584 - y1_output_root_mean_squared_error: 0.8914 - y2_output_root_mean_squared_error: 1.3307 - val_loss: 2.6894 - val_y1_output_loss: 0.5665 - val_y2_output_loss: 2.1393 - val_y1_output_root_mean_squared_error: 0.7357 - val_y2_output_root_mean_squared_error: 1.4657
# Epoch 112/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.3438 - y1_output_loss: 0.6021 - y2_output_loss: 1.7455 - y1_output_root_mean_squared_error: 0.7793 - y2_output_root_mean_squared_error: 1.3178 - val_loss: 5.5475 - val_y1_output_loss: 0.6725 - val_y2_output_loss: 4.8311 - val_y1_output_root_mean_squared_error: 0.8166 - val_y2_output_root_mean_squared_error: 2.2092
# Epoch 113/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.0007 - y1_output_loss: 0.5637 - y2_output_loss: 1.4385 - y1_output_root_mean_squared_error: 0.7473 - y2_output_root_mean_squared_error: 1.2009 - val_loss: 2.7249 - val_y1_output_loss: 0.7127 - val_y2_output_loss: 1.9417 - val_y1_output_root_mean_squared_error: 0.8447 - val_y2_output_root_mean_squared_error: 1.4182
# Epoch 114/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.1572 - y1_output_loss: 0.5923 - y2_output_loss: 1.5765 - y1_output_root_mean_squared_error: 0.7722 - y2_output_root_mean_squared_error: 1.2494 - val_loss: 3.2957 - val_y1_output_loss: 0.9809 - val_y2_output_loss: 2.3960 - val_y1_output_root_mean_squared_error: 0.9534 - val_y2_output_root_mean_squared_error: 1.5449
# Epoch 115/500
# 614/614 [==============================] - 0s 127us/sample - loss: 1.9360 - y1_output_loss: 0.5176 - y2_output_loss: 1.4237 - y1_output_root_mean_squared_error: 0.7221 - y2_output_root_mean_squared_error: 1.1894 - val_loss: 5.9649 - val_y1_output_loss: 1.1709 - val_y2_output_loss: 4.9457 - val_y1_output_root_mean_squared_error: 1.0459 - val_y2_output_root_mean_squared_error: 2.2070
# Epoch 116/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.0081 - y1_output_loss: 0.8955 - y2_output_loss: 2.0942 - y1_output_root_mean_squared_error: 0.9491 - y2_output_root_mean_squared_error: 1.4516 - val_loss: 4.3419 - val_y1_output_loss: 0.9934 - val_y2_output_loss: 3.2523 - val_y1_output_root_mean_squared_error: 0.9864 - val_y2_output_root_mean_squared_error: 1.8355
# Epoch 117/500
# 614/614 [==============================] - 0s 132us/sample - loss: 1.6055 - y1_output_loss: 0.4520 - y2_output_loss: 1.1542 - y1_output_root_mean_squared_error: 0.6742 - y2_output_root_mean_squared_error: 1.0728 - val_loss: 3.8702 - val_y1_output_loss: 0.5668 - val_y2_output_loss: 3.2074 - val_y1_output_root_mean_squared_error: 0.7427 - val_y2_output_root_mean_squared_error: 1.8217
# Epoch 118/500
# 614/614 [==============================] - 0s 142us/sample - loss: 2.1756 - y1_output_loss: 0.5210 - y2_output_loss: 1.6438 - y1_output_root_mean_squared_error: 0.7221 - y2_output_root_mean_squared_error: 1.2861 - val_loss: 2.6768 - val_y1_output_loss: 0.6184 - val_y2_output_loss: 1.9873 - val_y1_output_root_mean_squared_error: 0.7865 - val_y2_output_root_mean_squared_error: 1.4346
# Epoch 119/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.2101 - y1_output_loss: 0.6376 - y2_output_loss: 1.5519 - y1_output_root_mean_squared_error: 0.8022 - y2_output_root_mean_squared_error: 1.2516 - val_loss: 2.5133 - val_y1_output_loss: 0.6060 - val_y2_output_loss: 1.9090 - val_y1_output_root_mean_squared_error: 0.7604 - val_y2_output_root_mean_squared_error: 1.3911
# Epoch 120/500
# 614/614 [==============================] - 0s 136us/sample - loss: 1.7228 - y1_output_loss: 0.4023 - y2_output_loss: 1.3085 - y1_output_root_mean_squared_error: 0.6370 - y2_output_root_mean_squared_error: 1.1476 - val_loss: 3.1214 - val_y1_output_loss: 0.8276 - val_y2_output_loss: 2.3638 - val_y1_output_root_mean_squared_error: 0.8789 - val_y2_output_root_mean_squared_error: 1.5326
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.8104 - y1_output_loss: 0.2169 - y2_output_loss: 0.6098 - y1_output_root_mean_squared_error: 0.4647 - y2_output_root_mean_squared_error: 0.7710 - val_loss: 4.4199 - val_y1_output_loss: 0.6585 - val_y2_output_loss: 3.6815 - val_y1_output_root_mean_squared_error: 0.8174 - val_y2_output_root_mean_squared_error: 1.9370
# Epoch 462/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.5239 - y1_output_loss: 0.1228 - y2_output_loss: 0.4009 - y1_output_root_mean_squared_error: 0.3491 - y2_output_root_mean_squared_error: 0.6340 - val_loss: 2.1957 - val_y1_output_loss: 0.3290 - val_y2_output_loss: 1.8337 - val_y1_output_root_mean_squared_error: 0.5729 - val_y2_output_root_mean_squared_error: 1.3666
# Epoch 463/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3885 - y1_output_loss: 0.1120 - y2_output_loss: 0.2771 - y1_output_root_mean_squared_error: 0.3342 - y2_output_root_mean_squared_error: 0.5261 - val_loss: 1.4214 - val_y1_output_loss: 0.3727 - val_y2_output_loss: 1.0873 - val_y1_output_root_mean_squared_error: 0.5880 - val_y2_output_root_mean_squared_error: 1.0372
# Epoch 464/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.4357 - y1_output_loss: 0.1188 - y2_output_loss: 0.3136 - y1_output_root_mean_squared_error: 0.3455 - y2_output_root_mean_squared_error: 0.5624 - val_loss: 1.3903 - val_y1_output_loss: 0.2542 - val_y2_output_loss: 1.1015 - val_y1_output_root_mean_squared_error: 0.5068 - val_y2_output_root_mean_squared_error: 1.0646
# Epoch 465/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.4145 - y1_output_loss: 0.1102 - y2_output_loss: 0.3029 - y1_output_root_mean_squared_error: 0.3335 - y2_output_root_mean_squared_error: 0.5507 - val_loss: 1.0825 - val_y1_output_loss: 0.2026 - val_y2_output_loss: 0.8800 - val_y1_output_root_mean_squared_error: 0.4462 - val_y2_output_root_mean_squared_error: 0.9399
# Epoch 466/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.3960 - y1_output_loss: 0.1187 - y2_output_loss: 0.2760 - y1_output_root_mean_squared_error: 0.3452 - y2_output_root_mean_squared_error: 0.5262 - val_loss: 1.3988 - val_y1_output_loss: 0.3795 - val_y2_output_loss: 1.0602 - val_y1_output_root_mean_squared_error: 0.5970 - val_y2_output_root_mean_squared_error: 1.0210
# Epoch 467/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.4454 - y1_output_loss: 0.1238 - y2_output_loss: 0.3200 - y1_output_root_mean_squared_error: 0.3504 - y2_output_root_mean_squared_error: 0.5680 - val_loss: 1.4418 - val_y1_output_loss: 0.3093 - val_y2_output_loss: 1.1080 - val_y1_output_root_mean_squared_error: 0.5534 - val_y2_output_root_mean_squared_error: 1.0656
# Epoch 468/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.4234 - y1_output_loss: 0.1175 - y2_output_loss: 0.3037 - y1_output_root_mean_squared_error: 0.3418 - y2_output_root_mean_squared_error: 0.5537 - val_loss: 1.3730 - val_y1_output_loss: 0.2886 - val_y2_output_loss: 1.0448 - val_y1_output_root_mean_squared_error: 0.5411 - val_y2_output_root_mean_squared_error: 1.0393
# Epoch 469/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.6037 - y1_output_loss: 0.1501 - y2_output_loss: 0.4523 - y1_output_root_mean_squared_error: 0.3868 - y2_output_root_mean_squared_error: 0.6738 - val_loss: 1.6703 - val_y1_output_loss: 0.4831 - val_y2_output_loss: 1.1707 - val_y1_output_root_mean_squared_error: 0.6937 - val_y2_output_root_mean_squared_error: 1.0905
# Epoch 470/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.4691 - y1_output_loss: 0.1448 - y2_output_loss: 0.3327 - y1_output_root_mean_squared_error: 0.3771 - y2_output_root_mean_squared_error: 0.5717 - val_loss: 3.8699 - val_y1_output_loss: 0.8117 - val_y2_output_loss: 2.9630 - val_y1_output_root_mean_squared_error: 0.9096 - val_y2_output_root_mean_squared_error: 1.7443
# Epoch 471/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.4724 - y1_output_loss: 0.1346 - y2_output_loss: 0.3346 - y1_output_root_mean_squared_error: 0.3676 - y2_output_root_mean_squared_error: 0.5808 - val_loss: 1.3171 - val_y1_output_loss: 0.2848 - val_y2_output_loss: 1.0155 - val_y1_output_root_mean_squared_error: 0.5314 - val_y2_output_root_mean_squared_error: 1.0172
# Epoch 472/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3998 - y1_output_loss: 0.1087 - y2_output_loss: 0.2893 - y1_output_root_mean_squared_error: 0.3299 - y2_output_root_mean_squared_error: 0.5394 - val_loss: 1.5214 - val_y1_output_loss: 0.2727 - val_y2_output_loss: 1.2151 - val_y1_output_root_mean_squared_error: 0.5198 - val_y2_output_root_mean_squared_error: 1.1186
# Epoch 473/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3235 - y1_output_loss: 0.0996 - y2_output_loss: 0.2221 - y1_output_root_mean_squared_error: 0.3162 - y2_output_root_mean_squared_error: 0.4728 - val_loss: 1.2008 - val_y1_output_loss: 0.2122 - val_y2_output_loss: 0.9767 - val_y1_output_root_mean_squared_error: 0.4603 - val_y2_output_root_mean_squared_error: 0.9944
# Epoch 474/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3103 - y1_output_loss: 0.0960 - y2_output_loss: 0.2147 - y1_output_root_mean_squared_error: 0.3107 - y2_output_root_mean_squared_error: 0.4623 - val_loss: 1.2122 - val_y1_output_loss: 0.2375 - val_y2_output_loss: 0.9574 - val_y1_output_root_mean_squared_error: 0.4799 - val_y2_output_root_mean_squared_error: 0.9909
# Epoch 475/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3106 - y1_output_loss: 0.1004 - y2_output_loss: 0.2143 - y1_output_root_mean_squared_error: 0.3172 - y2_output_root_mean_squared_error: 0.4583 - val_loss: 1.2144 - val_y1_output_loss: 0.2337 - val_y2_output_loss: 0.9645 - val_y1_output_root_mean_squared_error: 0.4813 - val_y2_output_root_mean_squared_error: 0.9913
# Epoch 476/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.4234 - y1_output_loss: 0.1219 - y2_output_loss: 0.3003 - y1_output_root_mean_squared_error: 0.3482 - y2_output_root_mean_squared_error: 0.5496 - val_loss: 1.0910 - val_y1_output_loss: 0.1984 - val_y2_output_loss: 0.8783 - val_y1_output_root_mean_squared_error: 0.4443 - val_y2_output_root_mean_squared_error: 0.9453
# Epoch 477/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.3169 - y1_output_loss: 0.1020 - y2_output_loss: 0.2132 - y1_output_root_mean_squared_error: 0.3202 - y2_output_root_mean_squared_error: 0.4630 - val_loss: 1.3964 - val_y1_output_loss: 0.2658 - val_y2_output_loss: 1.1054 - val_y1_output_root_mean_squared_error: 0.5123 - val_y2_output_root_mean_squared_error: 1.0649
# Epoch 478/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3280 - y1_output_loss: 0.1006 - y2_output_loss: 0.2292 - y1_output_root_mean_squared_error: 0.3175 - y2_output_root_mean_squared_error: 0.4766 - val_loss: 1.3085 - val_y1_output_loss: 0.2931 - val_y2_output_loss: 1.0209 - val_y1_output_root_mean_squared_error: 0.5366 - val_y2_output_root_mean_squared_error: 1.0102
# Epoch 479/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3116 - y1_output_loss: 0.0993 - y2_output_loss: 0.2131 - y1_output_root_mean_squared_error: 0.3158 - y2_output_root_mean_squared_error: 0.4603 - val_loss: 2.4308 - val_y1_output_loss: 0.2689 - val_y2_output_loss: 2.0934 - val_y1_output_root_mean_squared_error: 0.5208 - val_y2_output_root_mean_squared_error: 1.4695
# Epoch 480/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3756 - y1_output_loss: 0.1170 - y2_output_loss: 0.2564 - y1_output_root_mean_squared_error: 0.3428 - y2_output_root_mean_squared_error: 0.5080 - val_loss: 1.1375 - val_y1_output_loss: 0.2184 - val_y2_output_loss: 0.9229 - val_y1_output_root_mean_squared_error: 0.4624 - val_y2_output_root_mean_squared_error: 0.9611
# Epoch 481/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.3522 - y1_output_loss: 0.1244 - y2_output_loss: 0.2267 - y1_output_root_mean_squared_error: 0.3544 - y2_output_root_mean_squared_error: 0.4761 - val_loss: 1.3753 - val_y1_output_loss: 0.2509 - val_y2_output_loss: 1.1435 - val_y1_output_root_mean_squared_error: 0.4913 - val_y2_output_root_mean_squared_error: 1.0649
# Epoch 482/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.4860 - y1_output_loss: 0.1276 - y2_output_loss: 0.3570 - y1_output_root_mean_squared_error: 0.3576 - y2_output_root_mean_squared_error: 0.5984 - val_loss: 1.5558 - val_y1_output_loss: 0.3260 - val_y2_output_loss: 1.2576 - val_y1_output_root_mean_squared_error: 0.5586 - val_y2_output_root_mean_squared_error: 1.1152
# Epoch 483/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.3819 - y1_output_loss: 0.1143 - y2_output_loss: 0.2667 - y1_output_root_mean_squared_error: 0.3365 - y2_output_root_mean_squared_error: 0.5183 - val_loss: 1.3756 - val_y1_output_loss: 0.4410 - val_y2_output_loss: 0.9453 - val_y1_output_root_mean_squared_error: 0.6512 - val_y2_output_root_mean_squared_error: 0.9755
# Epoch 484/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.3169 - y1_output_loss: 0.0999 - y2_output_loss: 0.2156 - y1_output_root_mean_squared_error: 0.3166 - y2_output_root_mean_squared_error: 0.4654 - val_loss: 1.1695 - val_y1_output_loss: 0.2319 - val_y2_output_loss: 0.9196 - val_y1_output_root_mean_squared_error: 0.4796 - val_y2_output_root_mean_squared_error: 0.9693
# Epoch 485/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3168 - y1_output_loss: 0.1070 - y2_output_loss: 0.2083 - y1_output_root_mean_squared_error: 0.3278 - y2_output_root_mean_squared_error: 0.4575 - val_loss: 1.2118 - val_y1_output_loss: 0.2431 - val_y2_output_loss: 0.9679 - val_y1_output_root_mean_squared_error: 0.4825 - val_y2_output_root_mean_squared_error: 0.9894
# Epoch 486/500
# 614/614 [==============================] - 0s 123us/sample - loss: 0.3542 - y1_output_loss: 0.1133 - y2_output_loss: 0.2394 - y1_output_root_mean_squared_error: 0.3375 - y2_output_root_mean_squared_error: 0.4901 - val_loss: 1.1756 - val_y1_output_loss: 0.2291 - val_y2_output_loss: 0.9421 - val_y1_output_root_mean_squared_error: 0.4748 - val_y2_output_root_mean_squared_error: 0.9748
# Epoch 487/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.5032 - y1_output_loss: 0.1458 - y2_output_loss: 0.3546 - y1_output_root_mean_squared_error: 0.3833 - y2_output_root_mean_squared_error: 0.5969 - val_loss: 1.3078 - val_y1_output_loss: 0.2084 - val_y2_output_loss: 1.0691 - val_y1_output_root_mean_squared_error: 0.4548 - val_y2_output_root_mean_squared_error: 1.0493
# Epoch 488/500
# 614/614 [==============================] - 0s 121us/sample - loss: 0.4132 - y1_output_loss: 0.1295 - y2_output_loss: 0.2860 - y1_output_root_mean_squared_error: 0.3605 - y2_output_root_mean_squared_error: 0.5322 - val_loss: 1.4054 - val_y1_output_loss: 0.3339 - val_y2_output_loss: 1.1070 - val_y1_output_root_mean_squared_error: 0.5668 - val_y2_output_root_mean_squared_error: 1.0412
# Epoch 489/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.3281 - y1_output_loss: 0.1029 - y2_output_loss: 0.2228 - y1_output_root_mean_squared_error: 0.3218 - y2_output_root_mean_squared_error: 0.4739 - val_loss: 1.1809 - val_y1_output_loss: 0.2376 - val_y2_output_loss: 0.9497 - val_y1_output_root_mean_squared_error: 0.4819 - val_y2_output_root_mean_squared_error: 0.9740
# Epoch 490/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.2933 - y1_output_loss: 0.0923 - y2_output_loss: 0.2013 - y1_output_root_mean_squared_error: 0.3036 - y2_output_root_mean_squared_error: 0.4485 - val_loss: 1.2286 - val_y1_output_loss: 0.2790 - val_y2_output_loss: 0.9638 - val_y1_output_root_mean_squared_error: 0.5160 - val_y2_output_root_mean_squared_error: 0.9809
# Epoch 491/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3369 - y1_output_loss: 0.0990 - y2_output_loss: 0.2370 - y1_output_root_mean_squared_error: 0.3138 - y2_output_root_mean_squared_error: 0.4883 - val_loss: 1.2822 - val_y1_output_loss: 0.3032 - val_y2_output_loss: 0.9708 - val_y1_output_root_mean_squared_error: 0.5421 - val_y2_output_root_mean_squared_error: 0.9942
# Epoch 492/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.4155 - y1_output_loss: 0.1235 - y2_output_loss: 0.2911 - y1_output_root_mean_squared_error: 0.3523 - y2_output_root_mean_squared_error: 0.5398 - val_loss: 1.2260 - val_y1_output_loss: 0.2424 - val_y2_output_loss: 0.9781 - val_y1_output_root_mean_squared_error: 0.4873 - val_y2_output_root_mean_squared_error: 0.9943
# Epoch 493/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3903 - y1_output_loss: 0.1167 - y2_output_loss: 0.2749 - y1_output_root_mean_squared_error: 0.3421 - y2_output_root_mean_squared_error: 0.5227 - val_loss: 2.1263 - val_y1_output_loss: 0.4220 - val_y2_output_loss: 1.7994 - val_y1_output_root_mean_squared_error: 0.6290 - val_y2_output_root_mean_squared_error: 1.3156
# Epoch 494/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.4176 - y1_output_loss: 0.1188 - y2_output_loss: 0.3030 - y1_output_root_mean_squared_error: 0.3460 - y2_output_root_mean_squared_error: 0.5458 - val_loss: 2.5958 - val_y1_output_loss: 0.2239 - val_y2_output_loss: 2.3157 - val_y1_output_root_mean_squared_error: 0.4732 - val_y2_output_root_mean_squared_error: 1.5401
# Epoch 495/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.4323 - y1_output_loss: 0.1069 - y2_output_loss: 0.3276 - y1_output_root_mean_squared_error: 0.3272 - y2_output_root_mean_squared_error: 0.5703 - val_loss: 1.6903 - val_y1_output_loss: 0.2362 - val_y2_output_loss: 1.4273 - val_y1_output_root_mean_squared_error: 0.4850 - val_y2_output_root_mean_squared_error: 1.2063
# Epoch 496/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.3990 - y1_output_loss: 0.1324 - y2_output_loss: 0.2663 - y1_output_root_mean_squared_error: 0.3638 - y2_output_root_mean_squared_error: 0.5164 - val_loss: 1.1638 - val_y1_output_loss: 0.3573 - val_y2_output_loss: 0.8277 - val_y1_output_root_mean_squared_error: 0.5823 - val_y2_output_root_mean_squared_error: 0.9082
# Epoch 497/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.3428 - y1_output_loss: 0.0956 - y2_output_loss: 0.2468 - y1_output_root_mean_squared_error: 0.3067 - y2_output_root_mean_squared_error: 0.4988 - val_loss: 1.3706 - val_y1_output_loss: 0.3125 - val_y2_output_loss: 1.0220 - val_y1_output_root_mean_squared_error: 0.5653 - val_y2_output_root_mean_squared_error: 1.0252
# Epoch 498/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3362 - y1_output_loss: 0.1014 - y2_output_loss: 0.2351 - y1_output_root_mean_squared_error: 0.3190 - y2_output_root_mean_squared_error: 0.4842 - val_loss: 1.1509 - val_y1_output_loss: 0.1950 - val_y2_output_loss: 0.9375 - val_y1_output_root_mean_squared_error: 0.4416 - val_y2_output_root_mean_squared_error: 0.9777
# Epoch 499/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.3236 - y1_output_loss: 0.1044 - y2_output_loss: 0.2202 - y1_output_root_mean_squared_error: 0.3222 - y2_output_root_mean_squared_error: 0.4688 - val_loss: 1.1985 - val_y1_output_loss: 0.2240 - val_y2_output_loss: 0.9874 - val_y1_output_root_mean_squared_error: 0.4651 - val_y2_output_root_mean_squared_error: 0.9910
# Epoch 500/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.4008 - y1_output_loss: 0.1182 - y2_output_loss: 0.2801 - y1_output_root_mean_squared_error: 0.3450 - y2_output_root_mean_squared_error: 0.5308 - val_loss: 1.1170 - val_y1_output_loss: 0.2673 - val_y2_output_loss: 0.8372 - val_y1_output_root_mean_squared_error: 0.5114 - val_y2_output_root_mean_squared_error: 0.9249

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 580us/sample - loss: 1.1170 - y1_output_loss: 0.2745 - y2_output_loss: 0.8541 - y1_output_root_mean_squared_error: 0.5114 - y2_output_root_mean_squared_error: 0.9249
# Loss = 1.1170078345707484, Y1_loss = 0.2745361328125, Y1_mse = 0.5113928914070129, Y2_loss = 0.8541023135185242, Y2_mse = 0.9249244332313538

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
